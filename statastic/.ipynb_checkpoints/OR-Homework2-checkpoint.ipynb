# %%
import gurobipy as gp 
from gurobipy import *
import pandas as pd
import numpy as np
import time
import datetime

# %%
I = 3
J = 10
b = np.array([5, 8, 4, 6, 3, 7, 6, 9, 5, 8]) #補0使得1對齊1
p = np.array([3, 6, 5, 4, 1, 8, 5, 12,7, 6])
K = 15

# %%
p1 = Model("p1")
a = []
w = p1.addVar(    lb = 0, vtype = GRB.CONTINUOUS, name = 'w')
a = p1.addVars(I, J, lb = 0, vtype = GRB.BINARY, name = 'a')

p1.setObjective(w , GRB.MAXIMIZE) 
p1.addConstrs( (w    <= quicksum(a[i, j]*b[j] for j in range(J))for i in range(I)), "w <= aij*bj")
p1.addConstrs((quicksum(a[i, j] for i in range(I)) <= 1 for j in range(J)), "aij")  
p1.addConstrs((quicksum(a[i, j]*p[j] for j in range(J)) <= K for i in range(I)), "aij*pj <= K")
p1.addConstr( (w    >= 0), "w >= 0" )
p1.optimize()

for var in p1.getVars():
    print(var.varName, '= %.2f' %var.x)
print("\n")
print("objective value(max w) = %.2f" %p1.objVal)
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (mac64[x86])
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 17 rows, 31 columns and 94 nonzeros
# Model fingerprint: 0xa26406cf
# Variable types: 1 continuous, 30 integer (30 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 16 rows, 31 columns, 93 nonzeros
# Variable types: 0 continuous, 31 integer (30 binary)
#
# Root relaxation: objective 1.741667e+01, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   17.41667    0    9   -0.00000   17.41667      -     -    0s
# H    0     0                      11.3333333   17.41667  53.7%     -    0s
# H    0     0                      12.3333333   17.41667  41.2%     -    0s
# H    0     0                      14.0000000   17.41667  24.4%     -    0s
#      0     0   17.33333    0   12   14.00000   17.33333  23.8%     -    0s
# H    0     0                      15.0000000   17.33333  15.6%     -    0s
# H    0     0                      16.0000000   17.33333  8.33%     -    0s
#      0     0   17.33333    0    9   16.00000   17.33333  8.33%     -    0s
#      0     0   17.33333    0   11   16.00000   17.33333  8.33%     -    0s
#      0     0   17.33333    0   10   16.00000   17.33333  8.33%     -    0s
#      0     0   17.33333    0    8   16.00000   17.33333  8.33%     -    0s
#      0     0   17.33333    0    9   16.00000   17.33333  8.33%     -    0s
#      0     0   17.33333    0   10   16.00000   17.33333  8.33%     -    0s
#      0     0   17.33333    0   14   16.00000   17.33333  8.33%     -    0s
#      0     0   17.33333    0   14   16.00000   17.33333  8.33%     -    0s
#      0     0   17.33333    0    8   16.00000   17.33333  8.33%     -    0s
#      0     2   17.33333    0    8   16.00000   17.33333  8.33%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 10
#   Implied bound: 1
#   MIR: 4
#   StrongCG: 1
#   RLT: 1
#
# Explored 12 nodes (299 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 16 15 14 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+01, best bound 1.600000000000e+01, gap 0.0000%
# w = 16.00
# a[0,0] = 1.00
# a[0,1] = 0.00
# a[0,2] = 0.00
# a[0,3] = 0.00
# a[0,4] = 0.00
# a[0,5] = 0.00
# a[0,6] = 1.00
# a[0,7] = 0.00
# a[0,8] = 1.00
# a[0,9] = 0.00
# a[1,0] = 0.00
# a[1,1] = 0.00
# a[1,2] = 0.00
# a[1,3] = 1.00
# a[1,4] = 1.00
# a[1,5] = 1.00
# a[1,6] = 0.00
# a[1,7] = 0.00
# a[1,8] = 0.00
# a[1,9] = 0.00
# a[2,0] = 0.00
# a[2,1] = 1.00
# a[2,2] = 0.00
# a[2,3] = 0.00
# a[2,4] = 0.00
# a[2,5] = 0.00
# a[2,6] = 0.00
# a[2,7] = 0.00
# a[2,8] = 0.00
# a[2,9] = 1.00
#
#
# objective value(max w) = 16.00
